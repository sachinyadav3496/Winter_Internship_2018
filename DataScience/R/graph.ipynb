# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from random import choice
x = [ var for var in range(100) ]

one = np.array([choice(x) for var in range(15)])
two = np.array([ choice(x) for var in range(15)])
three = np.array([choice(x) for var in range(15)])
k = np.array([one,two])
#plt.plot(one,color='red',label='one')
plt.plot(k,color='green',label='two')
plt.plot(three,color='yellow',label='three')

# %%
plt.legend()
plt.savefig('new_test.png')
plt.show()
